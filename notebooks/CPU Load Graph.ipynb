# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mm
import csv

# %%
f = open('CPULoad.csv')
try:
    reader = csv.reader(f)
    floats = []
    for row in reader:
        floats.append(map(float, row))
finally:
    f.close()

# %%
cpu = np.array(floats)

# %%
cpu.shape
# Out:
# (391, 2)

# %%
cpu.size

# %%
x = cpu[:,0]
y = cpu[:,1]

# %%
x.size
# Out:
# 391

# %%
y.size
# Out:
# 391

# %%
x = np.arange(0.0, 391, 1)

# %%
plt.plot(x,y)
# plt.ylim(-0,100)
# plt.xlim(10,40)
plt.xlabel('Time')
plt.ylabel('Load')
plt.title('CPU Load')
plt.show()
